# %% [markdown]
# # Data science tools and Ecosystem

# %% [markdown]
# In this notebook, Data science tools and Ecosystem are summarized

# %% [markdown]
# **Objectives:**
# * Understand concepts of data science
# * List popular languages for data science
# * Learn how to create markdown and code cells
# * Perform simple data transformatons
# * Learn how to write and run python code cells

# %% [markdown]
# Some of the popular languages that Data scientists use are:

# %% [markdown]
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data scientists include:

# %% [markdown]
# - Pandas
# - Numpy
# - Matplotlib
# - Scikit-learn

# %% [markdown]
# | Data Science tools|
# |-------------------|
# |Jupyter Notebook|
# |Rstudio|
# |VS Code|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in python

# %%
# This is a simple arithmetic to multiply then add integers
(3*4)+ 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# NAJJUKA WINNIE
